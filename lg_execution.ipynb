# %%
# Used for: control data preprocessing and model training, testing, and evaluation
# Dataset: data/cpsc_processed: 

# Dataset: data/op_09_classes/:
# - training/evaluation:
# - testing:

# Dataset: data/op_08_classes (without PVC class in testing data)
# - training/evaluation:
# - testing:

# %%
#prepare data for cpsc_processed:

#perform preprocessing,baseline on data/cpsc_processed
# %run "preprocess.py" --data-dir "data/cpsc_processed" 
# %run "baselines.py" --data-dir "data/cpsc_processed" --classifier 'all'
# Out:
# data/cpsc_processed/labels.csv
# Start training LR...
# Finding optimal thresholds on validation dataset...
# LR F1s: [np.float64(0.22077922077922077), np.float64(0.8292682926829268), np.float64(0.8695652173913043), np.float64(0.5652173913043478), np.float64(0.5714285714285714), np.float64(0.6357615894039735), np.float64(0.3708609271523179), np.float64(0.26666666666666666), np.float64(0.5963302752293578)]
# Avg F1: 0.5473197946709651
# Start training RF...
# Finding optimal thresholds on validation dataset...
# RF F1s: [np.float64(0.2413793103448276), np.float64(0.8296296296296296), np.float64(0.7804878048780488), np.float64(0.5838509316770186), np.float64(0.5426356589147286), np.float64(0.7619047619047619), np.float64(0.3741935483870968), np.float64(0.4827586206896552), np.float64(0.6305418719211823)]
# Avg F1: 0.5808202375941055
# Start training LGB...
# [LightGBM] [Info] Number of positive: 493, number of negative: 5010
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.033199 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 160375
# [LightGBM] [Info] Number of data points in the train set: 5503, number of used features: 636
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.089587 -> initscore=-2.318682
# [LightGBM] [Info] Start training from score -2.318682
# [LightGBM] [Info] Number of positive: 1476, number of negative: 4027
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.032166 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 160375
# [LightGBM] [Info] Number of data points in the train set: 5503, number of used features: 636
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.268217 -> initscore=-1.003686
# [LightGBM] [Info] Start training from score -1.003686
# [LightGBM] [Info] Number of positive: 183, number of negative: 5320
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.037159 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 160375
# [LightGBM] [Info] Number of data points in the train set: 5503, number of used features: 636
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.033255 -> initscore=-3.369742
# [LightGBM] [Info] Start training from score -3.369742
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 562, number of negative: 4941
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.034223 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 160375
# [LightGBM] [Info] Number of data points in the train set: 5503, number of used features: 636
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.102126 -> initscore=-2.173821
# [LightGBM] [Info] Start training from score -2.173821
# [LightGBM] [Info] Number of positive: 718, number of negative: 4785
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.033014 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 160375
# [LightGBM] [Info] Number of data points in the train set: 5503, number of used features: 636
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.130474 -> initscore=-1.896772
# [LightGBM] [Info] Start training from score -1.896772
# [LightGBM] [Info] Number of positive: 970, number of negative: 4533
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.031556 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 160375
# [LightGBM] [Info] Number of data points in the train set: 5503, number of used features: 636
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.176267 -> initscore=-1.541843
# [LightGBM] [Info] Start training from score -1.541843
# [LightGBM] [Info] Number of positive: 575, number of negative: 4928
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.032064 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 160375
# [LightGBM] [Info] Number of data points in the train set: 5503, number of used features: 636
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.104488 -> initscore=-2.148318
# [LightGBM] [Info] Start training from score -2.148318
# [LightGBM] [Info] Number of positive: 168, number of negative: 5335
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.032347 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 160375
# [LightGBM] [Info] Number of data points in the train set: 5503, number of used features: 636
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.030529 -> initscore=-3.458080
# [LightGBM] [Info] Start training from score -3.458080
# [LightGBM] [Info] Number of positive: 735, number of negative: 4768
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.033198 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 160375
# [LightGBM] [Info] Number of data points in the train set: 5503, number of used features: 636
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.133564 -> initscore=-1.869812
# [LightGBM] [Info] Start training from score -1.869812
# Finding optimal thresholds on validation dataset...
# LGB F1s: [np.float64(0.35714285714285715), np.float64(0.85995085995086), np.float64(0.8636363636363636), np.float64(0.6716417910447762), np.float64(0.593103448275862), np.float64(0.7787610619469026), np.float64(0.4032258064516129), np.float64(0.45454545454545453), np.float64(0.7157894736842105)]
# Avg F1: 0.6330885685198777
# Start training MLP...
# Finding optimal thresholds on validation dataset...
# MLP F1s: [np.float64(0.28169014084507044), np.float64(0.850632911392405), np.float64(0.8372093023255814), np.float64(0.6621621621621622), np.float64(0.5970149253731343), np.float64(0.7380952380952381), np.float64(0.42487046632124353), np.float64(0.5070422535211268), np.float64(0.6733668341708543)]
# Avg F1: 0.619120470467424

# %%
#prepare data for op_09_classes:

#perform preprocessing,baseline on the data, op_9_classes
# %run "preprocess.py" --data-dir "data/op_09_classes/train_dataset" 
# %run "preprocess.py" --data-dir "data/op_09_classes/test_dataset"

# %%
#perform baseline training on the data, op_9_classes
# %run "baselines.py" --data-dir "data/op_09_classes/train_dataset" --classifier 'all'
# Out:
# data/op_09_classes/train_dataset/labels.csv
# Generating expert features...
# 100%|██████████| 20336/20336 [30:59<00:00, 10.94it/s]
# Start training LR...
# Finding optimal thresholds on validation dataset...
# LR F1s: [np.float64(0.0851063829787234), np.float64(0.7326732673267327), np.float64(0.8461538461538461), np.float64(0.47572815533980584), np.float64(0.3232876712328767), np.float64(0.5106382978723404), np.float64(0.21238938053097345), np.float64(0.0029455081001472753), np.float64(0.9438439230160822)]
# Avg F1: 0.4591962702835031
# Start training RF...
# Finding optimal thresholds on validation dataset...
# RF F1s: [np.float64(0.058823529411764705), np.float64(0.7368421052631579), np.float64(0.8793103448275862), np.float64(0.3671497584541063), np.float64(0.29411764705882354), np.float64(0.5732484076433121), np.float64(0.19161676646706588), np.float64(0.0029455081001472753), np.float64(0.9493603411513859)]
# Avg F1: 0.4503793787085944
# Start training LGB...
# [LightGBM] [Info] Number of positive: 444, number of negative: 15824
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.089884 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 151620
# [LightGBM] [Info] Number of data points in the train set: 16268, number of used features: 620
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.027293 -> initscore=-3.573458
# [LightGBM] [Info] Start training from score -3.573458
# [LightGBM] [Info] Number of positive: 448, number of negative: 15820
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.088173 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 151620
# [LightGBM] [Info] Number of data points in the train set: 16268, number of used features: 620
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.027539 -> initscore=-3.564237
# [LightGBM] [Info] Start training from score -3.564237
# [LightGBM] [Info] Number of positive: 421, number of negative: 15847
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.093635 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 151620
# [LightGBM] [Info] Number of data points in the train set: 16268, number of used features: 620
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.025879 -> initscore=-3.628103
# [LightGBM] [Info] Start training from score -3.628103
# [LightGBM] [Info] Number of positive: 927, number of negative: 15341
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.089920 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 151620
# [LightGBM] [Info] Number of data points in the train set: 16268, number of used features: 620
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.056983 -> initscore=-2.806331
# [LightGBM] [Info] Start training from score -2.806331
# [LightGBM] [Info] Number of positive: 792, number of negative: 15476
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.091061 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 151620
# [LightGBM] [Info] Number of data points in the train set: 16268, number of used features: 620
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.048685 -> initscore=-2.972484
# [LightGBM] [Info] Start training from score -2.972484
# [LightGBM] [Info] Number of positive: 1205, number of negative: 15063
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.089726 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 151620
# [LightGBM] [Info] Number of data points in the train set: 16268, number of used features: 620
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.074072 -> initscore=-2.525762
# [LightGBM] [Info] Start training from score -2.525762
# [LightGBM] [Info] Number of positive: 631, number of negative: 15637
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.088021 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 151620
# [LightGBM] [Info] Number of data points in the train set: 16268, number of used features: 620
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.038788 -> initscore=-3.210089
# [LightGBM] [Info] Start training from score -3.210089
# [LightGBM] [Info] Number of positive: 23, number of negative: 16245
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.087697 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 151620
# [LightGBM] [Info] Number of data points in the train set: 16268, number of used features: 620
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.001414 -> initscore=-6.560046
# [LightGBM] [Info] Start training from score -6.560046
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 14471, number of negative: 1797
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.086534 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 151620
# [LightGBM] [Info] Number of data points in the train set: 16268, number of used features: 620
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.889538 -> initscore=2.086028
# [LightGBM] [Info] Start training from score 2.086028
# Finding optimal thresholds on validation dataset...
# LGB F1s: [np.float64(0.08443271767810026), np.float64(0.7524752475247525), np.float64(0.8828828828828829), np.float64(0.5185185185185185), np.float64(0.29955947136563876), np.float64(0.6172106824925816), np.float64(0.205607476635514), np.float64(0.0029455081001472753), np.float64(0.9556036816459123)]
# Avg F1: 0.4799151318715609
# Start training MLP...
# Finding optimal thresholds on validation dataset...
# MLP F1s: [np.float64(0.09395973154362416), np.float64(0.6666666666666666), np.float64(0.8387096774193549), np.float64(0.6220095693779905), np.float64(0.3254237288135593), np.float64(0.49283667621776506), np.float64(0.18354430379746836), np.float64(0.0029455081001472753), np.float64(0.9494787489975942)]
# Avg F1: 0.4639527345482411
